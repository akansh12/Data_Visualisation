# %% [markdown]
# # Data Visualization

# %% [markdown]
# When Creating a visual always remember:
#
# 1.Less is more effective
# 2.Less is more attractive
# 3.Less is more impactive

# %% [markdown]
# Matplotlib Architecture

# %% [markdown]
# 1.Backend Layer
# (FigureCanvas, Rndered,EVENT)
# 2.Artist Layer
# 3.Scripting Layer(pyplot)

# %%
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib notebook

# %%
plt.plot(5,5,'*')
# Out:
# <img src="data:image/png;base64,..." width="556">

# %%
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Plot 1')
# Out:
# Text(0.5, 1.0, 'Plot 1')
